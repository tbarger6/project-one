# %%
import pandas as pd
import matplotlib.pyplot as plt
import requests
import json
import numpy as np

# %%
#Define list of indicators you want to loop through
indicator_list = list(["NY.GDP.PCAP.CD","NY.GDP.MKTP.KD.ZG","SL.UEM.TOTL.MA.NE.ZS","SL.UEM.TOTL.FE.NE.ZS"])

#Define country that I'm interested in
country= "usa"

#Find base url for api
base_url = "http://api.worldbank.org/v2"

#Choose desired format
response_format = "json"

#Build api request 
request_url = f"{base_url}/country/{country}/indicator/{indicator}?format={response_format}"

# %%
request_url = f"{base_url}/country/{country}/indicator/{indicator}?format={response_format}"
request_url
# Out:
# 'http://api.worldbank.org/v2/country/usa/indicator/NY.GDP.MKTP.CD?format=json'

# %%
response = requests.get(request_url).json()

# %%
response
# Out:
# [{'page': 1,
#   'pages': 2,
#   'per_page': 50,
#   'total': 60,
#   'sourceid': '2',
#   'lastupdated': '2020-02-27'},
#  [{'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '2019',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '2018',
#    'value': 20544343456936.5,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '2017',
#    'value': 19485393853000,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '2016',
#    'value': 18707188235000,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '2015',
#    'value': 18219297584000,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '2014',
#    'value': 17521746534000,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '2013',
#    'value': 16784849190000,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '2012',
#    'value': 16197007349000,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '2011',
#    'value': 15542581104000,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '2010',
#    'value': 14992052727000,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '2009',
#    'value': 14448933025000,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '2008',
#    'value': 14712844084000,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '2007',
#    'value': 14451858650000,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '2006',
#    'value': 13814611414000,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '2005',
#    'value': 13036640229000,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '2004',
#    'value': 12213729147000,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '2003',
#    'value': 11458243878000,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '2002',
#    'value': 10936419054000,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '2001',
#    'value': 10581821399000,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '2000',
#    'value': 10252345464000,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '1999',
#    'value': 9630664202000,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '1998',
#    'value': 9062818211000,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '1997',
#    'value': 8577554463000,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '1996',
#    'value': 8073122000000,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '1995',
#    'value': 7639749000000,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '1994',
#    'value': 7287236000000,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '1993',
#    'value': 6858559000000,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '1992',
#    'value': 6520327000000,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '1991',
#    'value': 6158129000000,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '1990',
#    'value': 5963144000000,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '1989',
#    'value': 5641580000000,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '1988',
#    'value': 5236438000000,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '1987',
#    'value': 4855215000000,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '1986',
#    'value': 4579631000000,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '1985',
#    'value': 4338979000000,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '1984',
#    'value': 4037613000000,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '1983',
#    'value': 3634038000000,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '1982',
#    'value': 3343789000000,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '1981',
#    'value': 3207042000000,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '1980',
#    'value': 2857307000000,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '1979',
#    'value': 2627334000000,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '1978',
#    'value': 2351599000000,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '1977',
#    'value': 2081826000000,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '1976',
#    'value': 1873412000000,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '1975',
#    'value': 1684904000000,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '1974',
#    'value': 1545243000000,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '1973',
#    'value': 1425376000000,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '1972',
#    'value': 1279110000000,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '1971',
#    'value': 1164850000000,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0},
#   {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#    'country': {'id': 'US', 'value': 'United States'},
#    'countryiso3code': 'USA',
#    'date': '1970',
#    'value': 1073303000000,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 0}]]

# %%
final_response = response[1]
final_response
# Out:
# [{'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2019',
#   'value': None,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2018',
#   'value': 20544343456936.5,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2017',
#   'value': 19485393853000,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2016',
#   'value': 18707188235000,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2015',
#   'value': 18219297584000,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2014',
#   'value': 17521746534000,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2013',
#   'value': 16784849190000,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2012',
#   'value': 16197007349000,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2011',
#   'value': 15542581104000,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2010',
#   'value': 14992052727000,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2009',
#   'value': 14448933025000,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2008',
#   'value': 14712844084000,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2007',
#   'value': 14451858650000,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2006',
#   'value': 13814611414000,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2005',
#   'value': 13036640229000,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2004',
#   'value': 12213729147000,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2003',
#   'value': 11458243878000,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2002',
#   'value': 10936419054000,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2001',
#   'value': 10581821399000,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '2000',
#   'value': 10252345464000,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1999',
#   'value': 9630664202000,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1998',
#   'value': 9062818211000,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1997',
#   'value': 8577554463000,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1996',
#   'value': 8073122000000,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1995',
#   'value': 7639749000000,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1994',
#   'value': 7287236000000,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1993',
#   'value': 6858559000000,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1992',
#   'value': 6520327000000,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1991',
#   'value': 6158129000000,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1990',
#   'value': 5963144000000,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1989',
#   'value': 5641580000000,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1988',
#   'value': 5236438000000,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1987',
#   'value': 4855215000000,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1986',
#   'value': 4579631000000,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1985',
#   'value': 4338979000000,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1984',
#   'value': 4037613000000,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1983',
#   'value': 3634038000000,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1982',
#   'value': 3343789000000,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1981',
#   'value': 3207042000000,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1980',
#   'value': 2857307000000,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1979',
#   'value': 2627334000000,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1978',
#   'value': 2351599000000,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1977',
#   'value': 2081826000000,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1976',
#   'value': 1873412000000,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1975',
#   'value': 1684904000000,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1974',
#   'value': 1545243000000,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1973',
#   'value': 1425376000000,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1972',
#   'value': 1279110000000,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1971',
#   'value': 1164850000000,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0},
#  {'indicator': {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (current US$)'},
#   'country': {'id': 'US', 'value': 'United States'},
#   'countryiso3code': 'USA',
#   'date': '1970',
#   'value': 1073303000000,
#   'unit': '',
#   'obs_status': '',
#   'decimal': 0}]

# %%
df = pd.DataFrame(final_response)
df
# Out:
#                                             indicator  \
# 0   {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 1   {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 2   {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 3   {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 4   {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 5   {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 6   {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 7   {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 8   {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 9   {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 10  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 11  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 12  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 13  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 14  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 15  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 16  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 17  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 18  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 19  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 20  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 21  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 22  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 23  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 24  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 25  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 26  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 27  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 28  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 29  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 30  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 31  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 32  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 33  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 34  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 35  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 36  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 37  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 38  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 39  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 40  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 41  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 42  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 43  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 44  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 45  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 46  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 47  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 48  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
# 49  {'id': 'NY.GDP.MKTP.CD', 'value': 'GDP (curren...
#
#                                    country countryiso3code  date  \
# 0   {'id': 'US', 'value': 'United States'}             USA  2019
# 1   {'id': 'US', 'value': 'United States'}             USA  2018
# 2   {'id': 'US', 'value': 'United States'}             USA  2017
# 3   {'id': 'US', 'value': 'United States'}             USA  2016
# 4   {'id': 'US', 'value': 'United States'}             USA  2015
# 5   {'id': 'US', 'value': 'United States'}             USA  2014
# 6   {'id': 'US', 'value': 'United States'}             USA  2013
# 7   {'id': 'US', 'value': 'United States'}             USA  2012
# 8   {'id': 'US', 'value': 'United States'}             USA  2011
# 9   {'id': 'US', 'value': 'United States'}             USA  2010
# 10  {'id': 'US', 'value': 'United States'}             USA  2009
# 11  {'id': 'US', 'value': 'United States'}             USA  2008
# 12  {'id': 'US', 'value': 'United States'}             USA  2007
# 13  {'id': 'US', 'value': 'United States'}             USA  2006
# 14  {'id': 'US', 'value': 'United States'}             USA  2005
# 15  {'id': 'US', 'value': 'United States'}             USA  2004
# 16  {'id': 'US', 'value': 'United States'}             USA  2003
# 17  {'id': 'US', 'value': 'United States'}             USA  2002
# 18  {'id': 'US', 'value': 'United States'}             USA  2001
# 19  {'id': 'US', 'value': 'United States'}             USA  2000
# 20  {'id': 'US', 'value': 'United States'}             USA  1999
# 21  {'id': 'US', 'value': 'United States'}             USA  1998
# 22  {'id': 'US', 'value': 'United States'}             USA  1997
# 23  {'id': 'US', 'value': 'United States'}             USA  1996
# 24  {'id': 'US', 'value': 'United States'}             USA  1995
# 25  {'id': 'US', 'value': 'United States'}             USA  1994
# 26  {'id': 'US', 'value': 'United States'}             USA  1993
# 27  {'id': 'US', 'value': 'United States'}             USA  1992
# 28  {'id': 'US', 'value': 'United States'}             USA  1991
# 29  {'id': 'US', 'value': 'United States'}             USA  1990
# 30  {'id': 'US', 'value': 'United States'}             USA  1989
# 31  {'id': 'US', 'value': 'United States'}             USA  1988
# 32  {'id': 'US', 'value': 'United States'}             USA  1987
# 33  {'id': 'US', 'value': 'United States'}             USA  1986
# 34  {'id': 'US', 'value': 'United States'}             USA  1985
# 35  {'id': 'US', 'value': 'United States'}             USA  1984
# 36  {'id': 'US', 'value': 'United States'}             USA  1983
# 37  {'id': 'US', 'value': 'United States'}             USA  1982
# 38  {'id': 'US', 'value': 'United States'}             USA  1981
# 39  {'id': 'US', 'value': 'United States'}             USA  1980
# 40  {'id': 'US', 'value': 'United States'}             USA  1979
# 41  {'id': 'US', 'value': 'United States'}             USA  1978
# 42  {'id': 'US', 'value': 'United States'}             USA  1977
# 43  {'id': 'US', 'value': 'United States'}             USA  1976
# 44  {'id': 'US', 'value': 'United States'}             USA  1975
# 45  {'id': 'US', 'value': 'United States'}             USA  1974
# 46  {'id': 'US', 'value': 'United States'}             USA  1973
# 47  {'id': 'US', 'value': 'United States'}             USA  1972
# 48  {'id': 'US', 'value': 'United States'}             USA  1971
# 49  {'id': 'US', 'value': 'United States'}             USA  1970
#
#            value unit obs_status  decimal
# 0            NaN                        0
# 1   2.054434e+13                        0
# 2   1.948539e+13                        0
# 3   1.870719e+13                        0
# 4   1.821930e+13                        0
# 5   1.752175e+13                        0
# 6   1.678485e+13                        0
# 7   1.619701e+13                        0
# 8   1.554258e+13                        0
# 9   1.499205e+13                        0
# 10  1.444893e+13                        0
# 11  1.471284e+13                        0
# 12  1.445186e+13                        0
# 13  1.381461e+13                        0
# 14  1.303664e+13                        0
# 15  1.221373e+13                        0
# 16  1.145824e+13                        0
# 17  1.093642e+13                        0
# 18  1.058182e+13                        0
# 19  1.025235e+13                        0
# 20  9.630664e+12                        0
# 21  9.062818e+12                        0
# 22  8.577554e+12                        0
# 23  8.073122e+12                        0
# 24  7.639749e+12                        0
# 25  7.287236e+12                        0
# 26  6.858559e+12                        0
# 27  6.520327e+12                        0
# 28  6.158129e+12                        0
# 29  5.963144e+12                        0
# 30  5.641580e+12                        0
# 31  5.236438e+12                        0
# 32  4.855215e+12                        0
# 33  4.579631e+12                        0
# 34  4.338979e+12                        0
# 35  4.037613e+12                        0
# 36  3.634038e+12                        0
# 37  3.343789e+12                        0
# 38  3.207042e+12                        0
# 39  2.857307e+12                        0
# 40  2.627334e+12                        0
# 41  2.351599e+12                        0
# 42  2.081826e+12                        0
# 43  1.873412e+12                        0
# 44  1.684904e+12                        0
# 45  1.545243e+12                        0
# 46  1.425376e+12                        0
# 47  1.279110e+12                        0
# 48  1.164850e+12                        0
# 49  1.073303e+12                        0

# %%
usa_gdp = df[["date","value"]]
usa_gdp = usa_gdp.sort_values("date", ascending=True)
usa_gdp.head()
# Out:
#     date         value
# 49  1970  1.073303e+12
# 48  1971  1.164850e+12
# 47  1972  1.279110e+12
# 46  1973  1.425376e+12
# 45  1974  1.545243e+12

# %%
plt.plot(usa_gdp["date"],usa_gdp["value"])
